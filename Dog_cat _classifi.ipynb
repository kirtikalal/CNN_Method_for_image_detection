# %%
# !git clone "https://github.com/vadivukar/GV_DeepLearning/"
# Out:
# fatal: destination path 'GV_DeepLearning' already exists and is not an empty directory.

# %%
# !git clone https://github.com/laxmimerit/dog-cat-full-dataset
# Out:
# Cloning into 'dog-cat-full-dataset'...
# remote: Enumerating objects: 25027, done.
# remote: Total 25027 (delta 0), reused 0 (delta 0), pack-reused 25027
# Receiving objects: 100% (25027/25027), 541.62 MiB | 23.21 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Updating files: 100% (25001/25001), done.

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# Part 1 - Data Preprocessing
# Preprocessing the Training set

# %%
import pandas as pd

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory('/content/dog-cat-full-dataset/data/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 20000 images belonging to 2 classes.

# %% [markdown]
# Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/dog-cat-full-dataset/data/test',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 5000 images belonging to 2 classes.

# %% [markdown]
# Part 2 - Building the CNN
# Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', 
                               input_shape=[64, 64, 3]))

# %% [markdown]
# Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# Part 3 - Training the CNN
# Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 50)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.4905 - accuracy: 0.7643 - val_loss: 0.4675 - val_accuracy: 0.7768
# Epoch 2/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.4624 - accuracy: 0.7797 - val_loss: 0.4598 - val_accuracy: 0.7844
# Epoch 3/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.4456 - accuracy: 0.7897 - val_loss: 0.4243 - val_accuracy: 0.8090
# Epoch 4/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.4268 - accuracy: 0.8059 - val_loss: 0.4462 - val_accuracy: 0.7990
# Epoch 5/50
# 625/625 [==============================] - 97s 156ms/step - loss: 0.4101 - accuracy: 0.8102 - val_loss: 0.4138 - val_accuracy: 0.8120
# Epoch 6/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.3978 - accuracy: 0.8176 - val_loss: 0.4071 - val_accuracy: 0.8184
# Epoch 7/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.3814 - accuracy: 0.8271 - val_loss: 0.4405 - val_accuracy: 0.8004
# Epoch 8/50
# 625/625 [==============================] - 90s 144ms/step - loss: 0.3670 - accuracy: 0.8371 - val_loss: 0.4030 - val_accuracy: 0.8238
# Epoch 9/50
# 625/625 [==============================] - 96s 153ms/step - loss: 0.3565 - accuracy: 0.8432 - val_loss: 0.4412 - val_accuracy: 0.8020
# Epoch 10/50
# 625/625 [==============================] - 90s 143ms/step - loss: 0.3419 - accuracy: 0.8475 - val_loss: 0.4723 - val_accuracy: 0.7938
# Epoch 11/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.3295 - accuracy: 0.8562 - val_loss: 0.4174 - val_accuracy: 0.8188
# Epoch 12/50
# 625/625 [==============================] - 87s 140ms/step - loss: 0.3187 - accuracy: 0.8612 - val_loss: 0.4024 - val_accuracy: 0.8234
# Epoch 13/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.3047 - accuracy: 0.8676 - val_loss: 0.3872 - val_accuracy: 0.8324
# Epoch 14/50
# 625/625 [==============================] - 87s 140ms/step - loss: 0.2933 - accuracy: 0.8755 - val_loss: 0.3912 - val_accuracy: 0.8320
# Epoch 15/50
# 625/625 [==============================] - 90s 144ms/step - loss: 0.2856 - accuracy: 0.8787 - val_loss: 0.4528 - val_accuracy: 0.8140
# Epoch 16/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.2728 - accuracy: 0.8819 - val_loss: 0.4071 - val_accuracy: 0.8336
# Epoch 17/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.2653 - accuracy: 0.8867 - val_loss: 0.4789 - val_accuracy: 0.8086
# Epoch 18/50
# 625/625 [==============================] - 91s 145ms/step - loss: 0.2569 - accuracy: 0.8916 - val_loss: 0.3983 - val_accuracy: 0.8384
# Epoch 19/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.2389 - accuracy: 0.9023 - val_loss: 0.4744 - val_accuracy: 0.8182
# Epoch 20/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.2270 - accuracy: 0.9054 - val_loss: 0.5352 - val_accuracy: 0.8148
# Epoch 21/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.2228 - accuracy: 0.9083 - val_loss: 0.4286 - val_accuracy: 0.8372
# Epoch 22/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.2239 - accuracy: 0.9064 - val_loss: 0.4421 - val_accuracy: 0.8312
# Epoch 23/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.2075 - accuracy: 0.9137 - val_loss: 0.4557 - val_accuracy: 0.8282
# Epoch 24/50
# 625/625 [==============================] - 90s 145ms/step - loss: 0.2001 - accuracy: 0.9172 - val_loss: 0.4526 - val_accuracy: 0.8322
# Epoch 25/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.1955 - accuracy: 0.9209 - val_loss: 0.4905 - val_accuracy: 0.8204
# Epoch 26/50
# 625/625 [==============================] - 90s 143ms/step - loss: 0.1915 - accuracy: 0.9212 - val_loss: 0.5377 - val_accuracy: 0.8234
# Epoch 27/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.1851 - accuracy: 0.9257 - val_loss: 0.4731 - val_accuracy: 0.8368
# Epoch 28/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.1831 - accuracy: 0.9259 - val_loss: 0.5463 - val_accuracy: 0.8204
# Epoch 29/50
# 625/625 [==============================] - 89s 143ms/step - loss: 0.1678 - accuracy: 0.9338 - val_loss: 0.5145 - val_accuracy: 0.8288
# Epoch 30/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.1690 - accuracy: 0.9322 - val_loss: 0.4992 - val_accuracy: 0.8238
# Epoch 31/50
# 625/625 [==============================] - 89s 143ms/step - loss: 0.1601 - accuracy: 0.9351 - val_loss: 0.5979 - val_accuracy: 0.8176
# Epoch 32/50
# 625/625 [==============================] - 88s 140ms/step - loss: 0.1603 - accuracy: 0.9359 - val_loss: 0.6129 - val_accuracy: 0.8184
# Epoch 33/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.1513 - accuracy: 0.9404 - val_loss: 0.5571 - val_accuracy: 0.8272
# Epoch 34/50
# 625/625 [==============================] - 96s 154ms/step - loss: 0.1438 - accuracy: 0.9428 - val_loss: 0.5703 - val_accuracy: 0.8312
# Epoch 35/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.1436 - accuracy: 0.9438 - val_loss: 0.6123 - val_accuracy: 0.8214
# Epoch 36/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.1393 - accuracy: 0.9456 - val_loss: 0.5651 - val_accuracy: 0.8266
# Epoch 37/50
# 625/625 [==============================] - 88s 140ms/step - loss: 0.1326 - accuracy: 0.9480 - val_loss: 0.5604 - val_accuracy: 0.8360
# Epoch 38/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.1309 - accuracy: 0.9491 - val_loss: 0.6187 - val_accuracy: 0.8266
# Epoch 39/50
# 625/625 [==============================] - 88s 142ms/step - loss: 0.1228 - accuracy: 0.9524 - val_loss: 0.7084 - val_accuracy: 0.8066
# Epoch 40/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.1300 - accuracy: 0.9491 - val_loss: 0.5896 - val_accuracy: 0.8246
# Epoch 41/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.1179 - accuracy: 0.9553 - val_loss: 0.7183 - val_accuracy: 0.8134
# Epoch 42/50
# 625/625 [==============================] - 97s 155ms/step - loss: 0.1277 - accuracy: 0.9510 - val_loss: 0.6484 - val_accuracy: 0.8242
# Epoch 43/50
# 625/625 [==============================] - 89s 142ms/step - loss: 0.1172 - accuracy: 0.9545 - val_loss: 0.6299 - val_accuracy: 0.8244
# Epoch 44/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.1151 - accuracy: 0.9568 - val_loss: 0.6800 - val_accuracy: 0.8260
# Epoch 45/50
# 625/625 [==============================] - 88s 141ms/step - loss: 0.1146 - accuracy: 0.9571 - val_loss: 0.6753 - val_accuracy: 0.8204
# Epoch 46/50
# 625/625 [==============================] - 86s 137ms/step - loss: 0.1045 - accuracy: 0.9611 - val_loss: 0.7838 - val_accuracy: 0.8180
# Epoch 47/50
# 625/625 [==============================] - 86s 138ms/step - loss: 0.1029 - accuracy: 0.9601 - val_loss: 0.8189 - val_accuracy: 0.8110
# Epoch 48/50
# 625/625 [==============================] - 85s 137ms/step - loss: 0.1042 - accuracy: 0.9602 - val_loss: 0.6377 - val_accuracy: 0.8336
# Epoch 49/50
# 625/625 [==============================] - 85s 137ms/step - loss: 0.0968 - accuracy: 0.9633 - val_loss: 0.6696 - val_accuracy: 0.8264
# Epoch 50/50
# 625/625 [==============================] - 87s 139ms/step - loss: 0.0968 - accuracy: 0.9636 - val_loss: 0.6580 - val_accuracy: 0.8290

# %% [markdown]
# Part 4 - Making a single prediction

# %%
cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 813,217
# Trainable params: 813,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
from keras.preprocessing import image

test_image = tf.keras.utils.load_img('/content/dog-cat-full-dataset/data/test/dogs/dog.10081.jpg', 
                            target_size = (64, 64))
#test_image = tf.keras.utils.load_img(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 [==============================] - 0s 89ms/step

# %% [markdown]
# Double-click (or enter) to edit

# %%
print(prediction)
# Out:
# dog
